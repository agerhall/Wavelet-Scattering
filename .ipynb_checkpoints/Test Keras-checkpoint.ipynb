# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import compCNN2

# %% [markdown]
# # Initialization

# %%
# initialize parameters
img_x, img_y = 28, 28 # for mnist we have 28x28 images
batch_size = 10
epochs = 5
num_classes = 10

nb_out_chan = 16
kernel_size = (5, 5)

trainX, trainY, testX, testY, input_shape = compCNN2.mnistData(img_x, img_y, num_classes)

smallIdx = int(trainX.shape[0]*0.01)
smallTrainX = trainX[:smallIdx,:,:,:]
smallTrainY = trainY[:smallIdx]

# %%
plt.figure(figsize=(5, 5))
for i, ind in enumerate([0, 15, 50, 156, 159, 210, 250, 300, 489]):
    plt.subplot(3, 3, i+1)
    plt.xticks([])
    plt.yticks([])
    img = plt.imshow(smallTrainX[ind, :, :, 0], cmap = "hot")

# %%
# Define the model with a given architecture
CNNModel = compCNN2.arch1(input_shape, num_classes, nb_out_chan, kernel_size)
print(CNNModel.summary())

# train the model
CNNModel.fit(smallTrainX, smallTrainY, batch_size, epochs)

# evaluate the model performance
compCNN2.evalModel(CNNModel, testX, testY, batch_size)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 16)        112
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 14, 14, 32)        56
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               470700
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                3010
# =================================================================
# Total params: 478,934
# Trainable params: 478,850
# Non-trainable params: 84
# _________________________________________________________________
# None
# Epoch 1/5
# 600/600 [==============================] - 5s 8ms/step - loss: 1.0910 - acc: 0.7150
# Epoch 2/5
# 600/600 [==============================] - 3s 6ms/step - loss: 0.2331 - acc: 0.9250
# Epoch 3/5
# 600/600 [==============================] - 3s 5ms/step - loss: 0.0803 - acc: 0.9767
# Epoch 4/5
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0372 - acc: 0.9900
# Epoch 5/5
# 600/600 [==============================] - 3s 6ms/step - loss: 0.0430 - acc: 0.9867
# Results on test set:
# loss: 0.3839170415996923
# acc: 0.8971999938488007

# %% [markdown]
# # Convolutional layer 1

# %%
conv_layer1 = CNNModel.get_layer(index=0)
filter1 = conv_layer1.get_weights()[0] # Weights of the 1st convolution layer (without the bias)
chan1 = filter1.shape[3] # Number of output channels in convolution layer 1

fig = plt.figure(figsize=(10, 20))
sub_vert = (chan1+1)/2
sub_hori = 2
for i in range(chan1):
    ax = fig.add_subplot(sub_vert, sub_hori, i+1)
    ax.set_title("Output channel {}".format(i+1), fontsize=16)
    sns.heatmap(filter1[:, :, 0, i], vmin=-0.15, vmax=0.15, center=0, square=True, cmap="bwr")
    print("Output channel {}: Mean = {}, Standard deviation = {}".format(i+1, filter1[:, :, 0, i].mean(),
          filter1[:, :, 0, i].std()))
# Out:
# Output channel 1: Mean = -0.00265569519251585, Standard deviation = 0.04823450744152069
# Output channel 2: Mean = 0.00043907429790124297, Standard deviation = 0.05377983674407005
# Output channel 3: Mean = -2.197135290771257e-05, Standard deviation = 0.05479304492473602
# Output channel 4: Mean = -0.0012223029043525457, Standard deviation = 0.047468941658735275
# Output channel 5: Mean = 0.004220074974000454, Standard deviation = 0.049156904220581055
# Output channel 6: Mean = 0.0001942862872965634, Standard deviation = 0.045510679483413696
# Output channel 7: Mean = -1.4021992683410645e-05, Standard deviation = 0.04787786304950714
# Output channel 8: Mean = 0.004665970802307129, Standard deviation = 0.048090603202581406

# %% [markdown]
# # Convolutional layer 2

# %% [raw]
# conv_layer2 = CNNModel.get_layer(index=3)
# filter2 = conv_layer2.get_weights()[0] # Weights of the 2nd convolution layer (without the bias)
# img_x = filter2.shape[0] # Number of pixels in direction x
# img_y = filter2.shape[1] # Number of pixels in direction y
# inpchan2 = filter2.shape[2] # Number of input channels in convolution layer 2
# outchan2 = filter2.shape[3] # Number of output channels in convolution layer 2
#
# OUT_CHAN = 10 # Choice of the output channel
#
# fig = plt.figure(figsize=(15, 30))
# plt.subplots_adjust(top=1)
# nb_pix = img_x * img_y # Number of pixels per filter
# graph_index = 1
# for i in range(img_x):
#     for j in range(img_y):
#         ax = fig.add_subplot(nb_pix, 1, graph_index)
#         ax.set_title("Pixels ({}, {})".format(i+1, j+1), fontsize=14)
#         plt.plot(range(inpchan2), filter2[i, j, :, OUT_CHAN])
#         graph_index += 1

# %%
conv_layer2 = CNNModel.get_layer(index=3)
filter2 = conv_layer2.get_weights()[0] # Weights of the 2st convolution layer (without the bias)
chan2 = filter2.shape[3] # Number of output channels in convolution layer 1

fig = plt.figure(figsize=(15, 80))
sub_vert = (chan2+1)/2
sub_hori = 2
for i in range(chan2):
    ax = fig.add_subplot(sub_vert, sub_hori, i+1)
    ax.set_title("Output channel {}".format(i+1), fontsize=16)
    print(filter2[:, :, 0, i].min(), filter2[:, :, 0, i].max())
    sns.heatmap(filter2[:, :, 0, i], vmin=-0.15, vmax=0.15, center=0, square=True, cmap="bwr")
    #print("Output channel {}: Sum = {}, Standard deviation = {}".format(i+1, filter1[:, :, 0, i].sum(),
    #      filter1[:, :, 0, i].std()))
# Out:
# -0.11444182 0.09686988
# -0.14211938 0.1259545
# -0.10510588 0.105235524
# -0.12901478 0.12328387
# -0.10187443 0.11575921
# -0.10969909 0.117265835
# -0.1274695 0.123315275
# -0.09186293 0.08837649
# -0.12663193 0.046056446
# -0.1244598 0.057973783
# -0.1236459 0.123795904
# -0.12596138 0.13671814
# -0.08368431 0.12559259
# -0.011963659 0.117225215
# -0.11040557 0.13397843
# -0.12636502 0.10699235
# -0.1237943 0.10820007
# -0.10811171 0.11723822
# -0.112038895 0.14283316
# -0.10482337 0.09017544
# -0.09205307 0.05630737
# -0.10536558 0.07902266
# -0.08728452 0.10491703
# -0.10631703 0.023425063
# -0.13231836 0.11453045
# -0.08946477 0.111498974
# -0.11451261 0.13028634
# -0.10535969 0.119394675
# -0.14450173 0.11099763
# -0.07028553 0.0712573
# -0.13630147 0.08200753
# -0.084524415 0.08765329
